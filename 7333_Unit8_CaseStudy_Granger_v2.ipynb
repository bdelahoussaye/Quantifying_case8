# %% [markdown]
# # 7333 - Quantifying the World
# # Unit 8 Case Study
# # Authors: Brandon De La Houssaye, Bruce Granger, Daniel Serna

# %% [markdown]
# Required Packages

# %%
from pandas import datetime
from matplotlib import pyplot as plt
import matplotlib 
# %matplotlib inline

import pandas_profiling
import pandas as pd
from pathlib import Path
import numpy as np

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf, pacf
# Out:
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\pandas_profiling\plot.py:15: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\ipykernel\kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\tornado\platform\asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\asyncio\base_events.py", line 528, in run_forever
#     self._run_once()
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\asyncio\base_events.py", line 1764, in _run_once
#     handle._run()
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\tornado\gen.py", line 781, in inner
#     self.run()
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\tornado\gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\ipykernel\kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\ipykernel\kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\ipykernel\kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\IPython\core\interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\IPython\core\interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\IPython\core\interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\IPython\core\interactiveshell.py", line 3214, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\IPython\core\interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-455c3f7fbebe>", line 4, in <module>
#     get_ipython().run_line_magic('matplotlib', 'inline')
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\IPython\core\interactiveshell.py", line 2307, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\decorator.py:decorator-gen-109>", line 2, in matplotlib
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\IPython\core\magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\IPython\core\magics\pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\IPython\core\interactiveshell.py", line 3384, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\IPython\core\pylabtools.py", line 314, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\matplotlib\pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\matplotlib\__init__.py", line 1410, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\matplotlib\backends\__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use(BACKEND)

# %% [markdown]
# ## Injest Data

# %%
config = Path('./wmt.csv')

if config.is_file():
    wmt_temp = pd.read_csv("wmt.csv")
    wmt_temp.rename(columns={'date': 'Day'}, inplace=True)
    wmt_stock = wmt_temp['close']
    wmt_stock.index=pd.to_datetime(wmt_temp['Day'])
    print("Data was found locally and imported.")
else:
    # import yahoo_fin
    # import requests_html
    from yahoo_fin import stock_info as si
    Start_Date = '10/15/2015'; End_Date = '10/15/2019'
    wmt_temp = si.get_data("wmt", start_date = Start_Date, end_date = End_Date)
    wmt_temp.rename(columns={'date': 'Day'}, inplace=True)
    
    wmt_stock = wmt_temp['close']
    wmt_stock.reset_index(inplace=True)
    wmt_stock.index=pd.to_datetime(wmt_temp['Day'])
    wmt_data.to_csv("wmt.csv", index=False)
    print("Data was not found locally; data was downloaded and preserved as a CSV.")
# Out:
# Data was found locally and imported.

# %% [markdown]
# ## Question 1 - Intuition

# %%
def runArima(p, d, q, showRSS=False):  
    model = ARIMA(wmt_stock.dropna(), order=(p, d, q))  
    try:
        results_ARIMA = model.fit(disp=-1)
    except ValueError:
        pass
    except:
        pass
    
    if(showRSS):
        plt.plot(wmt_stock)
        plt.plot(results_ARIMA.fittedvalues, color='red')
        x=pd.DataFrame(results_ARIMA.fittedvalues)
        x=x.join(wmt_stock)
        x['out']=(x.iloc[:,0]-x.iloc[:,1])**2
        loss=np.sqrt(x['out'].sum())
        plt.title('RSS: %.4f'% loss)
    
    #from statsmodels.tsa.stattools import acf, pacf
    acf_wmt_plot = acf(results_ARIMA.fittedvalues, nlags=20)
    #Plot ACF: 
    plt.figure(figsize=(20, 4))

    plt.subplot(121) 
    plt.plot(acf_wmt_plot)
    plt.xticks(np.arange(21))
    plt.axhline(y=0,linestyle='--',color='gray')
    plt.axhline(y=-1.96/np.sqrt(len(acf_wmt_plot)),linestyle='--',color='gray')
    plt.axhline(y=1.96/np.sqrt(len(acf_wmt_plot)),linestyle='--',color='gray')
    for i in range(1,20):
        plt.axvline(x=i,linestyle=':',color='gray')
    plt.title('Autocorrelation Function')
    print(f"p:{p} d:{d} q:{q}")

# %% [markdown]
# ### We will first analyze results by adjusting the d parameter.

# %%
p = 0
d = 0
q = 0
runArima(p,d,q)
# Out:
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# p:0 d:0 q:0

# %% [markdown]
# Based on this autocorrelation plot with d=0, we see a stationary time series with a need for increased differencung. So we will re-run the ARIMAS model with d=1.

# %%
d = 1
runArima(p,d,q)
# Out:
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# p:0 d:1 q:0

# %%
d = 2
runArima(p,d,q)
# Out:
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# p:0 d:2 q:0

# %% [markdown]
# ## WMT Profile

# %%
profile = pandas_profiling.ProfileReport(wmt_temp)
profile
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>8 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>1006 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>63.0 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>64.1 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_adjclose"><code>adjclose</code></a> is highly correlated with <a href="#pp_var_close"><code>close</code></a> (ρ = 0.99883) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_close"><code>close</code></a> is highly correlated with <a href="#pp_var_low"><code>low</code></a> (ρ = 0.99942) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_high"><code>high</code></a> is highly correlated with <a href="#pp_var_open"><code>open</code></a> (ρ = 0.99941) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_low"><code>low</code></a> is highly correlated with <a href="#pp_var_high"><code>high</code></a> (ρ = 0.99919) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_ticker"><code>ticker</code></a> has constant value WMT <span class="label label-primary">Rejected</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Day">Day<br/>
#             <small>Categorical, Unique</small>
#         </p>
#     </div><div class="col-md-3 collapse in" id="miniv

# %% [markdown]
# ### Based Upon Brad's Example

# %%
print(wmt_stock.head())
fig = plt.figure()

wmt_stock.plot()
plt.title("Wal-Mart Stock Price Over Time")
plt.xlabel("Time")
plt.ylabel('WMT Stock Price')
plt.show()
# Out:
# Day
# 2015-10-15    59.330002
# 2015-10-16    58.889999
# 2015-10-19    58.849998
# 2015-10-20    58.750000
# 2015-10-21    58.639999
# Name: close, dtype: float64

# %% [markdown]
# This function implements the Dickey-Fuller test and plots data along with rolling mean and standard deviation

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    global dftest 
    
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(wmt_stock)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -0.419603
# p-value                           0.906774
# #Lags Used                        1.000000
# Number of Observations Used    1004.000000
# Critical Value (1%)              -3.436880
# Critical Value (5%)              -2.864423
# Critical Value (10%)             -2.568305
# dtype: float64

# %%
def test_stat_vs_crit_val():
    
    for key,value in dftest[4].items():
        if dftest[0] > value:
            print("The Test Statistic of", dftest[0], "is greater than the Critical Value", key, "value of", value)
        elif dftest[0] < value:
            print("The Test Statistic of", dftest[0], "is less than theCritical Value", key, "value of", value)

# %%
test_stat_vs_crit_val()
# Out:
# The Test Statistic of -0.41960301097381153 is greater than the Critical Value 1% value of -3.436879978012783
# The Test Statistic of -0.41960301097381153 is greater than the Critical Value 5% value of -2.86442302475405
# The Test Statistic of -0.41960301097381153 is greater than the Critical Value 10% value of -2.568305057578451

# %% [markdown]
# Now we will subtract the trend from our data to make it (more) stationary

# %%
moving_avg = wmt_stock.rolling(12).mean()
no_trend = wmt_stock - moving_avg
plt.plot(no_trend)
plt.title("WMT Stock Data with Rolling Mean Removed")
test_stationarity(no_trend.dropna())
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -9.259355e+00
# p-value                        1.420890e-15
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.940000e+02
# Critical Value (1%)           -3.436946e+00
# Critical Value (5%)           -2.864452e+00
# Critical Value (10%)          -2.568321e+00
# dtype: float64

# %%
test_stat_vs_crit_val()
# Out:
# The Test Statistic of -9.259354659446288 is less than theCritical Value 1% value of -3.43694584277544
# The Test Statistic of -9.259354659446288 is less than theCritical Value 5% value of -2.8644520725172873
# The Test Statistic of -9.259354659446288 is less than theCritical Value 10% value of -2.5683205291305176

# %% [markdown]
# Now we do a variable change from y to ln y.  Not that in python the "log" function is actually natural log, ln.  Also note that the test statistic did not change hardly at all, even though the series looks much better.

# %%
log_wmt_stock = np.log(wmt_stock)
log_moving_avg = log_wmt_stock.rolling(12).mean()
log_no_trend = log_wmt_stock - log_moving_avg
test_stationarity(log_no_trend.dropna())
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -9.530086e+00
# p-value                        2.906529e-16
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.940000e+02
# Critical Value (1%)           -3.436946e+00
# Critical Value (5%)           -2.864452e+00
# Critical Value (10%)          -2.568321e+00
# dtype: float64

# %%
test_stat_vs_crit_val()
# Out:
# The Test Statistic of -9.530086068900157 is less than theCritical Value 1% value of -3.43694584277544
# The Test Statistic of -9.530086068900157 is less than theCritical Value 5% value of -2.8644520725172873
# The Test Statistic of -9.530086068900157 is less than theCritical Value 10% value of -2.5683205291305176

# %% [markdown]
# This next set of charts simply shows all the pieces of the function.

# %%
# from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(wmt_stock, freq=30)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
plt.figure(num=None, figsize=(8, 10), dpi=80, facecolor='w', edgecolor='k')
plt.subplot(411)
plt.plot(wmt_stock, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# Next we will try some differencing to try and eliminate seasonality and make the series further stationary.  This determines if we use a difference term or not.  In this example, 1 shift ($y_t - y_{t-1}$) is used, so d=1

# %%
diff_wmt_stock = log_wmt_stock - log_wmt_stock.shift(1) # Changing the shift value is equivalent to changing your 'd' value
test_stationarity(diff_wmt_stock.dropna())
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -33.555238
# p-value                           0.000000
# #Lags Used                        0.000000
# Number of Observations Used    1004.000000
# Critical Value (1%)              -3.436880
# Critical Value (5%)              -2.864423
# Critical Value (10%)             -2.568305
# dtype: float64

# %%
test_stat_vs_crit_val()
# Out:
# The Test Statistic of -33.55523820435021 is less than theCritical Value 1% value of -3.436879978012783
# The Test Statistic of -33.55523820435021 is less than theCritical Value 5% value of -2.86442302475405
# The Test Statistic of -33.55523820435021 is less than theCritical Value 10% value of -2.568305057578451

# %% [markdown]
# Now we take a look at the Autocorrelation and Partial Autocorrelation plots

# %%
#from statsmodels.tsa.stattools import acf, pacf
acf_wmt_plot = acf(wmt_stock.dropna(), nlags=20)
#Plot ACF: 
plt.figure(figsize=(20, 4))

plt.subplot(121) 
plt.plot(acf_wmt_plot)
plt.xticks(np.arange(21))
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(acf_wmt_plot)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(acf_wmt_plot)),linestyle='--',color='gray')
for i in range(1,20):
    plt.axvline(x=i,linestyle=':',color='gray')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5,1,'Autocorrelation Function')

# %% [markdown]
# This indicates we have high positive correlations out to a high number of lags, meaning we need a higher value for d.

# %%
pacf_wmt_plot = pacf(diff_wmt_stock.dropna(), nlags=20)
#Plot ACF: 
plt.figure(figsize=(20, 4))

plt.subplot(121) 
plt.plot(pacf_wmt_plot)
plt.xticks(np.arange(21))
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(acf_wmt_plot)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(acf_wmt_plot)),linestyle='--',color='gray')
for i in range(1,20):
    plt.axvline(x=i,linestyle=':',color='gray')
plt.title('Partial Autocorrelation Function')
# Out:
# Text(0.5,1,'Partial Autocorrelation Function')

# %% [markdown]
# Now we fit a model of the proper order and look at the output

# %% [markdown]
# **NOT IN OUR CASE: **
#
# Since both the Autocorrelation and Partial Autocorrelation plots showed a drop at Lag 1 to within our confidence ranges - we'll start with a (1,0,1) ARIMA model.**  A (1,0,0) would likely fit equally well.

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model = ARIMA(diff_wmt_stock.dropna(), order=(1,0,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 1005
# Model:                     ARMA(1, 0)   Log Likelihood                2997.749
# Method:                       css-mle   S.D. of innovations              0.012
# Date:                Sat, 19 Oct 2019   AIC                          -5989.497
# Time:                        11:40:15   BIC                          -5974.759
# Sample:                             0   HQIC                         -5983.897
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0007      0.000      1.902      0.057   -2.11e-05       0.001
# ar.L1.close    -0.0583      0.031     -1.851      0.064      -0.120       0.003
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -17.1512           +0.0000j           17.1512            0.5000
# -----------------------------------------------------------------------------
#                   0
# count  1.005000e+03
# mean  -4.669275e-07
# std    1.226168e-02
# min   -1.072651e-01
# 25%   -5.923921e-03
# 50%    3.268276e-04
# 75%    5.899134e-03
# max    1.018964e-01

# %% [markdown]
# Now I am just going to do a brute force search for parameters and find the best  ones.

# %%
pdq_results = []

air_pop = wmt_stock.astype(float)
loss_best = 1E16
best_ints = [-1,-1,-1]
for p in range(4):
    for d in range(3):
        for q in range(3):
            model = ARIMA(diff_wmt_stock.dropna(), order=(p, d, q))  
            try:
                results_ARIMA = model.fit(disp=-1)
            except ValueError:
                pass
            except:
                pass
            plt.plot(diff_wmt_stock)
            plt.plot(results_ARIMA.fittedvalues, color='red')
            x=pd.DataFrame(results_ARIMA.fittedvalues)
            x=x.join(diff_wmt_stock)
            x['out']=(x.iloc[:,0]-x.iloc[:,1])**2
            loss=np.sqrt(x['out'].sum())
            plt.title('RSS: %.4f'% loss)
            pdq_results.append(f"p:{p} d:{d} q:{q} p+q:{p+q} rss:{loss} aic:{results_ARIMA.aic}")
            if loss < loss_best:
                print(loss)
                loss_best = loss
                best_ints=[p,d,q]
            plt.show()
            print(p,d,q)
# Out:
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0.38918557256972686
# 0 0 0
# 0.3884684697277932
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 0 1
# 0.388162944436776
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 0 2
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 1 0
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 1 1
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 1 2
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 2 0
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 2 1
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0 2 2
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 0 0
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0.38789756788219454
# 1 0 1
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 0 2
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 1 0
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 1 1
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\base\model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# 1 1 2
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 2 0
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 2 1
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1 2 2
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 0 0
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0.38789270882697113
# 2 0 1
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\base\model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 0 2
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 1 0
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 1 1
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 1 2
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 2 0
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 2 1
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2 2 2
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 0 0
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 0.38786531685104886
# 3 0 1
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\base\model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 3 0 2
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 1 0
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 3 1 1
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\base\model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# 3 1 2
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 2 0
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 2 1
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\envs\mltest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3 2 2

# %%
# print(pdq_results)
print(len(pdq_results))
for result in pdq_results:
    print(result)
# Out:
# 36
# p:0 d:0 q:0 p+q:0 rss:0.38918557256972686 aic:-5988.075070458797
# p:0 d:0 q:1 p+q:1 rss:0.3884684697277932 aic:-5989.779808854744
# p:0 d:0 q:2 p+q:2 rss:0.388162944436776 aic:-5989.358334135986
# p:0 d:1 q:0 p+q:0 rss:0.38973849936358196 aic:-5228.7993758523035
# p:0 d:1 q:1 p+q:1 rss:0.5342165036267401 aic:-5972.223173500337
# p:0 d:1 q:2 p+q:2 rss:0.5342165036267401 aic:-5972.223173500337
# p:0 d:2 q:0 p+q:0 rss:0.3897735970058275 aic:-4113.674890830392
# p:0 d:2 q:1 p+q:1 rss:0.6807423446691193 aic:-5213.6790899504795
# p:0 d:2 q:2 p+q:2 rss:0.6807423446691193 aic:-5213.6790899504795
# p:1 d:0 q:0 p+q:1 rss:0.3885231605975606 aic:-5989.4971927682855
# p:1 d:0 q:1 p+q:2 rss:0.38789756788219454 aic:-5990.729562811488
# p:1 d:0 q:2 p+q:3 rss:0.38789756788219454 aic:-5990.729562811488
# p:1 d:1 q:0 p+q:1 rss:0.4814101464415677 aic:-5530.461779935955
# p:1 d:1 q:1 p+q:2 rss:0.5446556972973449 aic:-5973.162281478721
# p:1 d:1 q:2 p+q:3 rss:0.5383672366754664 aic:-5964.517769020646
# p:1 d:2 q:0 p+q:1 rss:0.7644934220601306 aic:-4712.07780472784
# p:1 d:2 q:1 p+q:2 rss:0.7644934220601306 aic:-4712.07780472784
# p:1 d:2 q:2 p+q:3 rss:0.7644934220601306 aic:-4712.07780472784
# p:2 d:0 q:0 p+q:2 rss:0.38824200381869084 aic:-5988.950047796572
# p:2 d:0 q:1 p+q:3 rss:0.38789270882697113 aic:-5988.7544383881395
# p:2 d:0 q:2 p+q:4 rss:0.3878956670487134 aic:-5986.739272392242
# p:2 d:1 q:0 p+q:2 rss:0.5074966233923666 aic:-5654.912725361553
# p:2 d:1 q:1 p+q:3 rss:0.5492522443271268 aic:-5971.3316244489615
# p:2 d:1 q:2 p+q:4 rss:0.5440808783707607 aic:-5967.325719813305
# p:2 d:2 q:0 p+q:2 rss:0.8474739048144022 aic:-5011.047979068364
# p:2 d:2 q:1 p+q:3 rss:0.8474739048144022 aic:-5011.047979068364
# p:2 d:2 q:2 p+q:4 rss:0.8474739048144022 aic:-5011.047979068364
# p:3 d:0 q:0 p+q:3 rss:0.3880680408611074 aic:-5987.848670120415
# p:3 d:0 q:1 p+q:4 rss:0.38786531685104886 aic:-5986.8956018551635
# p:3 d:0 q:2 p+q:5 rss:0.3880786164746099 aic:-5983.7826325179885
# p:3 d:1 q:0 p+q:3 rss:0.5197668569129332 aic:-5717.751040601566
# p:3 d:1 q:1 p+q:4 rss:0.5480698984018653 aic:-5969.698684042929
# p:3 d:1 q:2 p+q:5 rss:0.5480823775491025 aic:-5954.910267027513
# p:3 d:2 q:0 p+q:3 rss:0.8833857007249865 aic:-5173.916429631952
# p:3 d:2 q:1 p+q:4 rss:0.8833857007249865 aic:-5173.916429631952
# p:3 d:2 q:2 p+q:5 rss:0.8833857007249865 aic:-5173.916429631952

# %%
print(loss_best)
print(best_ints)
# Out:
# 0.38786531683767067
# [3, 0, 1]

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
for param in pdq:
   for param_seasonal in seasonal_pdq:
       try:
           mod = sm.tsa.statespace.SARIMAX(y,order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
           results = mod.fit()
           print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
       except:
           continue
